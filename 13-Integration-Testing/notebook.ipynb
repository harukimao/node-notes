# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```js
# // In package.json
# "scripts": {
#     "test": "jest --watchAll --verbose"
# }
# ```

# %% [markdown]
# npm i supertest --save--dev
#
# - genres.test.js
# ```js
#
# const request = require('supertest');
# let server;
#     describe('/api/genres', () => {
#     beforeEach(() => { server = require('../../index'); }) afterEach(() => { server.close(); });
#     describe('GET /', () => {
#     it('should return all genres', async () => {
#     const res = await request(server).get('/api/genres'); expect(res.status).toBe (200);
#     });
#     });
# });
# ```

# %% [markdown]
# ------------------------------------
#
# ```js
# describe('/api/genres', () => {
#     beforeEach(() => { server = require('../../index'); }) afterEach(async() server.close();
#     });
#     await Genre.remove({});
#     describe('GET /', () => {
#     it('should return all genres', async () => {
#     await Genre.collection.insertMany([
#     ]);
#     { name: 'genre1' },
#     { name: 'genre2' },
#     const res = await request (server).get('/api/genres');
#     expect(res.status).toBe (200);
#     expect(res.body.length).toBe (2);
#     });
#     expect(res.body.some(g => g.name === 'genre1')).toBeTruthy();
# });
# });
# ```

# %% [markdown]
# --------------------------------------------------
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Validating Object IDs
#
# ![image.png](attachment:image.png)
#
# --------------------------------------
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### Testing invalid inputs
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ----
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Writing clean tests
# ![image.png](attachment:image.png)
#
# Add
#
# ```js
# beforeEach(() => {
#     token = new User().generateAuthToken();
# })

# %% [markdown]
# # Oh wait
#
# test: "jest --watchAll --verbose --coverage"
#
# shows how much of our code is covered by jest
#
# in .gitignore /coverage to not upload to git
